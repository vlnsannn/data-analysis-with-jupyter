# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import datetime

# %%
df1=pd.read_csv("matches.csv")
df1
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df2=pd.read_csv("deliveries.csv")
df2
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
df1.describe()
# Out:
#                  id       season  dl_applied  win_by_runs  win_by_wickets
# count    756.000000   756.000000  756.000000   756.000000      756.000000
# mean    1792.178571  2013.444444    0.025132    13.283069        3.350529
# std     3464.478148     3.366895    0.156630    23.471144        3.387963
# min        1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%      189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%      378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%      567.250000  2016.000000    0.000000    19.000000        6.000000
# max    11415.000000  2019.000000    1.000000   146.000000       10.000000

# %%
df2.describe()
# Out:
#             match_id         inning           over           ball  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean     1802.252957       1.482952      10.162488       3.615587
# std      3472.322805       0.502074       5.677684       1.806966
# min         1.000000       1.000000       1.000000       1.000000
# 25%       190.000000       1.000000       5.000000       2.000000
# 50%       379.000000       1.000000      10.000000       4.000000
# 75%       567.000000       2.000000      15.000000       5.000000
# max     11415.000000       5.000000      20.000000       9.000000
#
#        is_super_over      wide_runs       bye_runs    legbye_runs  \
# count  179078.000000  179078.000000  179078.000000  179078.000000
# mean        0.000452       0.036721       0.004936       0.021136
# std         0.021263       0.251161       0.116480       0.194908
# min         0.000000       0.000000       0.000000       0.000000
# ...

# %%
df1.fillna(0)
# Out:
#         id  season           city        date                        team1  \
# 0        1    2017      Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1        2    2017           Pune  2017-04-06               Mumbai Indians
# 2        3    2017         Rajkot  2017-04-07                Gujarat Lions
# 3        4    2017         Indore  2017-04-08       Rising Pune Supergiant
# 4        5    2017      Bangalore  2017-04-08  Royal Challengers Bangalore
# ..     ...     ...            ...         ...                          ...
# 751  11347    2019         Mumbai    05/05/19        Kolkata Knight Riders
# 752  11412    2019        Chennai    07/05/19          Chennai Super Kings
# 753  11413    2019  Visakhapatnam    08/05/19          Sunrisers Hyderabad
# 754  11414    2019  Visakhapatnam    10/05/19               Delhi Capitals
# 755  11415    2019      Hyderabad    12/05/19               Mumbai Indians
#
# ...

# %%
df2.fillna(0)
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %%
year_2008 = df1.loc[df1["season"]==2008, 'city']
year_2008
# Out:
# 59      Bangalore
# 60     Chandigarh
# 61          Delhi
# 62         Mumbai
# 63        Kolkata
# 64         Jaipur
# 65      Hyderabad
# 66        Chennai
# 67      Hyderabad
# 68     Chandigarh
# 69      Bangalore
# 70        Chennai
# 71         Mumbai
# 72     Chandigarh
# 73      Bangalore
# 74        Kolkata
# 75          Delhi
# 76      Hyderabad
# 77         Jaipur
# 78        Chennai
# 79      Hyderabad
# 80     Chandigarh
# 81         Mumbai
# 82         Jaipur
# 83      Bangalore
# 84        Chennai
# 85         Mumbai
# 86          Delhi
# 87        Kolkata
# 88         Jaipur
# 89      Bangalore
# 90        Chennai
# 91      Hyderabad
# 92         Jaipur
# 93     Chandigarh
# 94        Kolkata
# 95         Mumbai
# 96     Chandigarh
# 97          Delhi
# 98         Mumbai
# 99          Delhi
# 100        Jaipur
# 101     Hyderabad
# 102       Kolkata
# 103     Bangalore
# 104       Kolkata
# 105        Mumbai
# 106       Chennai
# 107    Chandigarh
# 108         Delhi
# ...

# %%
print("The number of matches played in 2008 is:")
year_2008.count()
# Out:
# The number of matches played in 2008 is:
# 58

# %%
print("City where maximum matches conducted:")
df1['city'].value_counts().idxmax()
# Out:
# City where maximum matches conducted:
# 'Mumbai'

# %%
print("City where minimum matches conducted:")
df1['city'].value_counts().idxmin()
# Out:
# City where minimum matches conducted:
# 'Bloemfontein'

# %%
print("Total count of matches city wise:")
df1['city'].value_counts()
# Out:
# Total count of matches city wise:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Centurion          12
# Ahmedabad          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cuttack             7
# Ranchi              7
# Port Elizabeth      7
# Cape Town           7
# Abu Dhabi           7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
print("Team with maximum toss wins:")
df1['toss_winner'].value_counts().idxmax()
# Out:
# Team with maximum toss wins:
# 'Mumbai Indians'

# %%
print("Team with minimum toss wins:")
df1['toss_winner'].value_counts().idxmin()
# Out:
# Team with minimum toss wins:
# 'Rising Pune Supergiant'

# %%
print("Toss decisions taken by Mumbai Indians:")
x=df1.loc[df1["toss_winner"]=="Mumbai Indians", 'toss_decision']
y=x.value_counts()
print(y)
plt.title('Mumbai Indians')
y.plot.pie()
plt.show()
# Out:
# Toss decisions taken by Mumbai Indians:
# field    54
# bat      44
# Name: toss_decision, dtype: int64

# %%
print("Toss decisions taken by Rising Pune Supergiant:")
x=df1.loc[df1["toss_winner"]=="Rising Pune Supergiant", 'toss_decision']
y=x.value_counts()
print(y)
plt.title('Rising Pune Supergiant')
y.plot.pie()
plt.show()
# Out:
# Toss decisions taken by Rising Pune Supergiant:
# field    6
# Name: toss_decision, dtype: int64

# %%
print("Number of normal matches: ")
df1['result'].loc[df1['result']=="normal"].value_counts()
# Out:
# Number of normal matches:
# normal    743
# Name: result, dtype: int64

# %%
print("Number of tie matches: ")
df1['result'].loc[df1['result']=="tie"].value_counts()
# Out:
# Number of tie matches:
# tie    9
# Name: result, dtype: int64

# %%
df1[['result', 'team1', 'team2']].loc[df1['result']=="tie"]
# Out:
#     result                        team1                        team2
# 33     tie                Gujarat Lions               Mumbai Indians
# 125    tie             Rajasthan Royals        Kolkata Knight Riders
# 189    tie              Kings XI Punjab          Chennai Super Kings
# 387    tie  Royal Challengers Bangalore          Sunrisers Hyderabad
# 400    tie             Delhi Daredevils  Royal Challengers Bangalore
# 475    tie             Rajasthan Royals        Kolkata Knight Riders
# 535    tie             Rajasthan Royals              Kings XI Punjab
# 705    tie        Kolkata Knight Riders               Delhi Capitals
# 746    tie               Mumbai Indians          Sunrisers Hyderabad

# %%
maxruns=df1['win_by_runs'].max()
maxruns_team = df1['winner'].loc[df1['win_by_runs'].idxmax()]
maxruns_team
# Out:
# 'Mumbai Indians'

# %%
print("Teams who won by the lowest runs and frequency: ")
df3=df1.loc[df1['win_by_runs']!=0]
y=df3['win_by_runs'].loc[df3.win_by_runs.idxmin()]
x=df3['winner'].loc[df3['win_by_runs']==y]
x.value_counts()
# Out:
# Teams who won by the lowest runs and frequency:
# Mumbai Indians                 3
# Kings XI Punjab                2
# Royal Challengers Bangalore    2
# Delhi Daredevils               1
# Chennai Super Kings            1
# Gujarat Lions                  1
# Name: winner, dtype: int64

# %%
print("Players that have more than 3 POTM's: ")
x=df1['player_of_match'].value_counts()
y=x.loc[x>3]
y
# Out:
# Players that have more than 3 POTM's:
# CH Gayle          21
# AB de Villiers    20
# RG Sharma         17
# MS Dhoni          17
# DA Warner         17
#                   ..
# SK Warne           4
# CA Lynn            4
# SS Iyer            4
# ML Hayden          4
# KH Pandya          4
# Name: player_of_match, Length: 65, dtype: int64

# %%
print("Player that has the most POTM's: ")
df1['player_of_match'].value_counts().idxmax()
# Out:
# Player that has the most POTM's:
# 'CH Gayle'

# %%
print("Venue where the team won by highest runs: ")
df1['venue'].loc[df1['win_by_runs'].idxmax()]
# Out:
# Venue where the team won by highest runs:
# 'Feroz Shah Kotla'

# %%
print("Venue where the team won by lowest runs: ")
df1['venue'].loc[df1['win_by_runs'].idxmin()]
# Out:
# Venue where the team won by lowest runs:
# 'Maharashtra Cricket Association Stadium'

# %%
x=df1['umpire1'].value_counts().idxmax()
y=df1['umpire2'].value_counts().idxmax()
z=df1['umpire3'].value_counts().idxmax()
print("Umpires who did maximum umpiring are: ")
print(x)
print(y)
print(z)
# Out:
# Umpires who did maximum umpiring are:
# HDPK Dharmasena
# C Shamshuddin
# Nitin Menon

# %%
plt.figure(figsize=(8,8))
plot=sns.countplot(x='season',data=df1,palette='Reds')
plot.bar_label(plot.containers[0])
plt.title('Total matches played in each season')
plt.show()

# %%
runs=df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [36], in <cell line: 3>()
#       1 convert={'season':int}
#       2 df3 = df3.astype(convert)
# ----> 3 runs=df3.groupby(by='season').total_runs.sum()
#       4 runs
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'total_runs'

# %%
x=df1['toss_winner'].value_counts()
x
# Out:
# Mumbai Indians                 98
# Kolkata Knight Riders          92
# Chennai Super Kings            89
# Royal Challengers Bangalore    81
# Kings XI Punjab                81
# Delhi Daredevils               80
# Rajasthan Royals               80
# Sunrisers Hyderabad            46
# Deccan Chargers                43
# Pune Warriors                  20
# Gujarat Lions                  15
# Delhi Capitals                 10
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %%
x=pd.crosstab(df1.season,df1.toss_decision)
x=pd.crosstab(df1.season,df1.toss_decision)
y=x.plot.bar(figsize=(10,8),rot=0)
y.set_title('Toss decision across seasons')
plt.show()

# %%
new_df=df2.drop(df2[df2['dismissal_kind'] == "not out"].index)
x=new_df['dismissal_kind'].value_counts()
x
# Out:
# caught                   5348
# bowled                   1581
# run out                   852
# lbw                       540
# stumped                   278
# caught and bowled         211
# retired hurt               12
# hit wicket                 10
# obstructing the field       2
# Name: dismissal_kind, dtype: int64

# %%
plt.figure(figsize=(10,10))
mylabels = ['caught','bowled','run out','lbw','stumped','caught and bowled','retired hurt','hit wicket','obstructing the field']
plt.pie(x,labels=x)
plt.legend(title='Dismissal',labels=mylabels,loc='center',bbox_to_anchor=(0.5,-0.1),ncol=2)
plt.show()

# %%
topbatsman=df2.groupby('batsman').batsman_runs.sum()
top_10=topbatsman.sort_values(ascending=False).head(10)
top_10
# Out:
# batsman
# V Kohli           5434
# SK Raina          5415
# RG Sharma         4914
# DA Warner         4741
# S Dhawan          4632
# CH Gayle          4560
# MS Dhoni          4477
# RV Uthappa        4446
# AB de Villiers    4428
# G Gambhir         4223
# Name: batsman_runs, dtype: int64

# %%
plt.figure(figsize=(6,6))
plot=top_10.plot.bar()
plot.bar_label(plot.containers[0])
plt.title('Top 10 batsman in IPL')
plt.show()

# %%
x=df1['player_of_match'].value_counts().head(5)
x.plot.bar()
plt.title('Top 5 MOM awards winners')
plt.show()

# %%
team1 = df1['team1'].value_counts()
team2 = df1['team2'].value_counts()
total_matches = team1 + team2
x = total_matches.sort_values(ascending=False)
x
# Out:
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# Delhi Daredevils               161
# Rajasthan Royals               147
# Sunrisers Hyderabad            108
# Deccan Chargers                 75
# Pune Warriors                   46
# Gujarat Lions                   30
# Delhi Capitals                  16
# Rising Pune Supergiant          16
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# dtype: int64

# %%
plt.figure(figsize=(8,8))
plot=x.plot.bar()
plot.bar_label(plot.containers[0])
plt.title('Total Number of Played Matches by each team')
plt.show()

# %%
df=pd.DataFrame()
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
matches1 = df1['team1'].value_counts()
matches2 = df1['team2'].value_counts()
total = matches1+matches2
win_matches=df1['winner'].value_counts()
win_rate=(win_matches/total)*100
df['totalmatches']=total
df['winmatches']=win_matches
df['winrate']=win_rate
df
# Out:
#                              totalmatches  winmatches    winrate
# Chennai Super Kings                   164         100  60.975610
# Deccan Chargers                        75          29  38.666667
# Delhi Capitals                         16          10  62.500000
# Delhi Daredevils                      161          67  41.614907
# Gujarat Lions                          30          13  43.333333
# Kings XI Punjab                       176          82  46.590909
# Kochi Tuskers Kerala                   14           6  42.857143
# Kolkata Knight Riders                 178          92  51.685393
# Mumbai Indians                        187         109  58.288770
# Pune Warriors                          46          12  26.086957
# Rajasthan Royals                      147          75  51.020408
# Rising Pune Supergiant                 16          10  62.500000
# Rising Pune Supergiants                14           5  35.714286
# ...

# %%
df.plot.bar(figsize=(12,10),title='Total Matches vs Won Matches vs Win Rate')
plt.show()

# %%
x=df1['winner'].value_counts()
x
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
x= df1.city.value_counts().sum()
y= df1.loc[df1['result']=='normal'].value_counts().sum()
ratio=x/y
ratio
# Out:
# 6.456896551724138

# %%
x=pd.crosstab(df1.toss_winner,df1.toss_decision)
x
# Out:
# toss_decision                bat  field
# toss_winner
# Chennai Super Kings           48     41
# Deccan Chargers               24     19
# Delhi Capitals                 2      8
# Delhi Daredevils              29     51
# Gujarat Lions                  1     14
# Kings XI Punjab               26     55
# Kochi Tuskers Kerala           3      5
# Kolkata Knight Riders         30     62
# Mumbai Indians                44     54
# Pune Warriors                 11      9
# Rajasthan Royals              32     48
# Rising Pune Supergiant         0      6
# Rising Pune Supergiants        3      4
# Royal Challengers Bangalore   20     61
# Sunrisers Hyderabad           20     26
